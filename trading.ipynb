# %%
# %pip install vnstock gym_anytrading -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from time import time
from enum import IntEnum
from vnstock import Vnstock
from typing import Tuple, List, Dict

from gymnasium import spaces
import gymnasium as gym

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
from matplotlib.dates import DateFormatter

from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.evaluation import evaluate_policy


import warnings
warnings.filterwarnings('ignore')

# Lấy danh sách mã cổ phiếu từ Vnstock
stock = Vnstock().stock(source='VCI')

df = stock.listing.all_symbols()
ticker_list = df["ticker"].tolist()

# In ra danh sách mã cổ phiếu
print(ticker_list)
# Out:
# 2025-03-19 09:29:32 - vnstock.common.vnstock - INFO - Mã chứng khoán không được chỉ định, chương trình mặc định sử dụng VN30F1M
# 2025-03-19 09:29:32 - vnstock.common.data.data_explorer - INFO - Mã chứng khoán không được chỉ định, chương trình mặc định sử dụng VN30F1M
# 2025-03-19 09:29:32 - vnstock.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ['A32', 'AAA', 'AAH', 'AAM', 'AAS', 'AAT', 'AAV', 'ABA', 'ABB', 'ABC', 'ABI', 'ABR', 'ABS', 'ABT', 'ABW', 'ACB', 'ACC', 'ACE', 'ACG', 'ACL', 'ACM', 'ACS', 'ACV', 'ADC', 'ADG', 'ADP', 'ADS', 'AFX', 'AG1', 'AGE', 'AGF', 'AGG', 'AGM', 'AGP', 'AGR', 'AGX', 'AIC', 'AIG', 'ALT', 'ALV', 'AMC', 'AMD', 'AME', 'AMP', 'AMS', 'AMV', 'ANT', 'ANV', 'APC', 'APF', 'APG', 'APH', 'API', 'APL', 'APP', 'APS', 'APT', 'ARM', 'ART', 'ASA', 'ASG', 'ASM', 'ASP', 'AST', 'ATA', 'ATB', 'ATG', 'ATP', 'ATS', 'AVC', 'AVF', 'AVG', 'B82', 'BAB', 'BAF', 'BAL', 'BAX', 'BBC', 'BBH', 'BBM', 'BBS', 'BBT', 'BCA', 'BCB', 'BCC', 'BCE', 'BCF', 'BCG', 'BCH', 'BCM', 'BCO', 'BCP', 'BCR', 'BCV', 'BDB', 'BDG', 'BDT', 'BDW', 'BED', 'BEL', 'BFC', 'BGE', 'BGT', 'BGW', 'BHA', 'BHC', 'BHG', 'BHI', 'BHK', 'BHN', 'BHP', 'BIC', 'BID', 'BIG', 'BII', 'BIO', 'BKC', 'BKG', 'BKH', 'BLF', 'BLI', 'BLN', 'BLT', 'BLW', 'BMC', 'BMD', 'BMF', 'BMG', 'BMI', 'BMJ', 'BMK', 'BMN', 'BMP', 'BMS', 'BMV', 'BNA', 'BNW', 'BOT', 'BPC', 'BQB', 'BRC', 'BRR', 'BRS', 'BSA', 'BSC', 'BSD', 'BSG', 'BSH', 'BSI', 'BSL', 'BSP', 'BSQ', 'BSR', 'BST', 'BT1', 'BT6', 'BTB', 'BTD', 'BTG', 'BTH', 'BTN', 'BTP', 'BTS', 'BTT', 'BTU', 'BTV', 'BTW', 'BVB', 'BVG', 'BVH', 'BVL', 'BVN', 'BVS', 'BWA', 'BWE', 'BWS', 'BXH', 'C12', 'C21', 'C22', 'C32', 'C47', 'C4G', 'C69', 'C92', 'CAB', 'CAD', 'CAF', 'CAG', 'CAN', 'CAP', 'CAR', 'CAT', 'CAV', 'CBI', 'CBS', 'CBV', 'CC1', 'CC4', 'CCA', 'CCC', 'CCD', 'CCI', 'CCL', 'CCM', 'CCP', 'CCR', 'CCS', 'CCT', 'CCV', 'CDC', 'CDG', 'CDH', 'CDN', 'CDO', 'CDP', 'CDR', 'CE1', 'CEG', 'CEN', 'CEO', 'CET', 'CFM', 'CFV', 'CGV', 'CH5', 'CHC', 'CHP', 'CHS', 'CI5', 'CIA', 'CID', 'CIG', 'CII', 'CIP', 'CJC', 'CK8', 'CKA', 'CKD', 'CKG', 'CKV', 'CLC', 'CLG', 'CLH', 'CLL', 'CLM', 'CLW', 'CLX', 'CMC', 'CMD', 'CMF', 'CMG', 'CMI', 'CMK', 'CMM', 'CMN', 'CMP', 'CMS', 'CMT', 'CMV', 'CMW', 'CMX', 'CNA', 'CNC', 'CNG', 'CNN', 'CNT', 'COM', 'CPA', 'CPC', 'CPH', 'CPI', 'CQN', 'CQT', 'CRC', 'CRE', 'CRV', 'CSC', 'CSI', 'CSM', 'CST', 'CSV', 'CT3', 'CT6', 'CTA', 'CTB', 'CTC', 'CTD', 'CTF', 'CTG', 'CTI', 'CTN', 'CTP', 'CTR', 'CTS', 'CTT', 'CTW', 'CTX', 'CVN', 'CVT', 'CX8', 'CYC', 'D11', 'D2D', 'DAC', 'DAD', 'DAE', 'DAG', 'DAH', 'DAN', 'DAS', 'DAT', 'DBC', 'DBD', 'DBM', 'DBT', 'DC1', 'DC2', 'DC4', 'DCF', 'DCG', 'DCH', 'DCL', 'DCM', 'DCR', 'DCS', 'DCT', 'DDB', 'DDG', 'DDH', 'DDM', 'DDN', 'DDV', 'DFC', 'DFF', 'DGC', 'DGT', 'DGW', 'DHA', 'DHB', 'DHC', 'DHD', 'DHG', 'DHM', 'DHN', 'DHP', 'DHQ', 'DHT', 'DIC', 'DID', 'DIG', 'DIH', 'DKC', 'DKW', 'DL1', 'DLD', 'DLG', 'DLM', 'DLR', 'DLT', 'DM7', 'DMC', 'DMH', 'DMN', 'DMS', 'DNA', 'DNC', 'DND', 'DNE', 'DNH', 'DNL', 'DNM', 'DNN', 'DNP', 'DNT', 'DNW', 'DO3', 'DOC', 'DOP', 'DP1', 'DP2', 'DP3', 'DPC', 'DPG', 'DPH', 'DPM', 'DPP', 'DPR', 'DPS', 'DQC', 'DRC', 'DRG', 'DRH', 'DRI', 'DRL', 'DS3', 'DSC', 'DSD', 'DSE', 'DSG', 'DSN', 'DSP', 'DST', 'DSV', 'DTA', 'DTB', 'DTC', 'DTD', 'DTE', 'DTG', 'DTH', 'DTI', 'DTK', 'DTL', 'DTP', 'DTT', 'DTV', 'DUS', 'DVC', 'DVG', 'DVM', 'DVN', 'DVP', 'DVW', 'DWC', 'DWS', 'DXG', 'DXL', 'DXP', 'DXS', 'DXV', 'DZM', 'E12', 'E29', 'EBS', 'ECI', 'ECO', 'EFI', 'EGL', 'EIB', 'EIC', 'EID', 'EIN', 'ELC', 'EME', 'EMG', 'EMS', 'EPC', 'EPH', 'ESL', 'EVE', 'EVF', 'EVG', 'EVS', 'FBA', 'FBC', 'FCC', 'FCM', 'FCN', 'FCS', 'FDC', 'FGL', 'FHH', 'FHN', 'FHS', 'FIC', 'FID', 'FIR', 'FIT', 'FLC', 'FMC', 'FOC', 'FOX', 'FPT', 'FRC', 'FRM', 'FRT', 'FSO', 'FT1', 'FTI', 'FTM', 'FTS', 'FVN', 'G20', 'G30', 'G36', 'GAB', 'GAS', 'GCB', 'GCF', 'GDA', 'GDT', 'GDW', 'GEE', 'GEG', 'GER', 'GEX', 'GGG', 'GH3', 'GHC', 'GIC', 'GIL', 'GKM', 'GLC', 'GLT', 'GLW', 'GMA', 'GMC', 'GMD', 'GMH', 'GMX', 'GND', 'GPC', 'GSM', 'GSP', 'GTA', 'GTD', 'GTS', 'GTT', 'GVR', 'GVT', 'H11', 'HAC', 'HAD', 'HAF', 'HAG', 'HAH', 'HAI', 'HAM', 'HAN', 'HAP', 'HAR', 'HAS', 'HAT', 'HAV', 'HAX', 'HBC', 'HBD', 'HBH', 'HBS', 'HC1', 'HC3', 'HCB', 'HCC', 'HCD', 'HCI', 'HCM', 'HCO', 'HCT', 'HD2', 'HD6', 'HD8', 'HDA', 'HDB', 'HDC', 'HDG', 'HDM', 'HDO', 'HDP', 'HDS', 'HDW', 'HEC', 'HEJ', 'HEM', 'HEP', 'HES', 'HEV', 'HFB', 'HFC', 'HFX', 'HGM', 'H ...

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Lấy dữ liệu chứng khoán FPT từ VCI
stock = Vnstock().stock(symbol='FPT', source='VCI')
df = stock.quote.history(start='2017-01-01', end='2024-01-01')

#Đổi tên cột thoả mãn với gym anytrading
df.rename(columns={
    'time': 'Date',
    'open': 'Open', # Việt Nam Đồng
    'high': 'High',
    'low': 'Low',
    'close': 'Close',
    'volume': 'Volume'
}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])  # Chuyển đổi sang định dạng datetime
df.set_index('Date', inplace=True)  # Đặt cột Date làm index
df
# Out:
# 2025-03-19 09:29:33 - vnstock.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
#              Open   High    Low  Close   Volume
# Date
# 2017-01-03  11.33  11.50  11.33  11.47  1013070
# 2017-01-04  11.46  11.69  11.43  11.57  1022560
# 2017-01-05  11.56  11.61  11.53  11.53   613870
# 2017-01-06  11.56  11.64  11.50  11.50   799750
# 2017-01-09  11.52  11.61  11.48  11.56   501610
# ...           ...    ...    ...    ...      ...
# 2023-12-25  81.39  82.51  81.30  82.33  2019931
# 2023-12-26  82.76  84.56  82.68  83.36  3364283
# 2023-12-27  83.53  83.88  83.11  83.11  1359748
# 2023-12-28  83.19  83.19  82.59  82.85  1199164
# 2023-12-29  82.85  83.19  82.42  82.42  1869204
#
# [1750 rows x 5 columns]

# %%
class Actions(IntEnum):
    """
    Định nghĩa các hành động mà môi trường có thể thực hiện
    """
    Sell = 0
    Buy = 1
    Hold = 2


class Positions(IntEnum):
    """
    Vị thế của môi trường
    """
    Short = 2
    Long = 1
    Flat = 0

    def opposite(self):
        if self == Positions.Long:
            return Positions.Short
        elif self == Positions.Short:
            return Positions.Long
        else:
            return Positions.Flat # Trung lập (không làm gì)

# %%
class TradingEnv(gym.Env):
    metadata = {'render_modes': ['human'], 'render_fps': 3}
    
    def __init__(
        self, 
        df: pd.DataFrame,
        window_size: int, 
        frame_bound: tuple,
        initial_balance: int, # Số dư ban đầu
        max_shares: int, # Số lượng cổ phiếu nắm giữ tối đa
        render_mode = None
    ):
        assert render_mode is None or render_mode in self.metadata['render_modes']
        
        self.render_mode = render_mode
        self.window_size = window_size
        self.frame_bound = frame_bound
        self.initial_balance = initial_balance # Số dư ban đầu
        self.max_shares = max_shares 

        # Khởi tạo các giá trị chỉ số kỹ thuật
        self.df = self.add_technical_indicators(df)
        self.prices, self.signal_features = self._process_data()
        self.shape = (self.window_size, self.signal_features.shape[1])
        super().__init__()

        # Định nghĩa không gian hành động
        self.action_space = spaces.Discrete(len(Actions))  # 0 = Buy, 1 = Sell, 2 = Hold
        
        self.observation_space = spaces.Box(
            low = - np.inf,
            high = np.inf,
            shape = self.shape,
            dtype = np.float32
        )
        
        # Episode
        self._start_tick = self.window_size
        self._end_tick = len(self.prices) - 1
        self._truncated = None
        self._current_tick = None
        self._last_trade_tick = None
        self._position = None
        self._position_history = None
        self._total_reward = None
        self._total_profit = None
        self._first_rendering = None
        self.history = None
        
        # Phí giao dịch
        self.trade_fee_bid_percent = 0.01 # Phí mua
        self.trade_fee_ask_percent = 0.005 # Phí bán

        # Khởi tạo các giá trị thống kê
        self._balance = None # Số dư hiện tại
        self._shares_held = None # Số lượng cổ phiếu đang nắm giữ
        self._portfolio_value = None # Giá trị danh mục
        self._cost_basis = None # Giá vốn
        self._last_action = Actions.Hold.value # Hành động cuối cùng
        self._prev_portfolio_value = None # Giá trị danh mục trước
        self._peak_portfolio_value = 0 # Đỉnh giá trị danh mục
        
        self._position_size = 0 # Số lượng cổ phiếu đang nắm giữ (short)
        self._total_profit = 1.0 # Lợi nhuận tổng cộng
        
    def add_technical_indicators(self, df: pd.DataFrame):
        """
        Cập nhật các chỉ số kỹ thuật vào dữ liệu
        """
        def _calculate_rsi(prices: pd.Series, window_size: int =14, epsilon: float = 1e-10) -> pd.Series:
            """
            Tính chỉ số RSI
            Dùng để xác định xem một cổ phiếu có overbought hay oversold không
            
            RSI > 70: Overbought
            RSI < 30: Oversold
            RSI ~= 40-60: Neutral
            """
            delta = prices.diff()
            gain = (delta.where(delta > 0, 0)).fillna(0)
            loss = (-delta.where(delta < 0, 0)).fillna(0)
            avg_gain = gain.rolling(window = window_size).mean()
            avg_loss = loss.rolling(window = window_size).mean()
            rs = avg_gain / (avg_loss + epsilon)
            rsi = 100 - (100 / (1 + rs))
            return rsi

        def _calculate_macd(prices: pd.Series, short_window: int = 12, long_window: int = 26, signal_window: int = 9) -> Tuple[pd.Series, pd.Series]:
            """
            Tính chỉ số MACD
            Dùng để xác định xu hướng giá, tín hiệu mua bán và động lượng của tài sản
            """
            short_ema = prices.ewm(span= short_window, adjust = False).mean() # 12 phiên
            long_ema = prices.ewm(span = long_window, adjust = False).mean() # 26 phiên
            macd = short_ema - long_ema
            macd_signal = macd.ewm(span = signal_window, adjust = False).mean()
            return macd, macd_signal

        def _calculate_bollinger_bands(prices: pd.Series, window_size: int = 20) -> Tuple[pd.Series, pd.Series, pd.Series]:
            """
            Tính chỉ số Bollinger Bands
            Giúp đo lường độ biến động (volatility) của giá và xác định vùng quá mua/quá bán
            """
            sma = prices.rolling(window = window_size).mean() # 20 phiên
            std = prices.rolling(window = window_size).std()
            upper_band = sma + (std * 2)
            lower_band = sma - (std * 2)
            return upper_band, lower_band, sma

        def _calculate_atr(high: pd.Series, low: pd.Series, close: pd.Series, window_size: int = 14) -> pd.Series:
            """
            Chỉ Average True Range
            Đo lường biến động của giá, không chỉ ra hướng mà cho thấy biên độ giá dao động
            """
            tr1 = high - low
            tr2 = abs(high - close.shift())
            tr3 = abs(low - close.shift())
            tr = pd.DataFrame({'tr1': tr1, 'tr2': tr2, 'tr3': tr3}).max(axis = 1)
            atr = tr.rolling(window = window_size).mean()
            return atr

        def _calculate_volatility(prices: pd.Series, window_size: int =20) -> pd.Series:
            """
            Tính độ biến động của giá
            """
            log_returns = np.log(prices / prices.shift(1))
            return log_returns.rolling(window = window_size).std() * np.sqrt(252)

        # Cập nhật các chỉ số kỹ thuật
        df = df.copy()
        df['RSI'] = _calculate_rsi(df['Close'])
        df['MACD'], df['MACD_Signal'] = _calculate_macd(df['Close'])
        df['MACD_Hist'] = df['MACD'] - df['MACD_Signal']
        df['BB_Upper'], df['BB_Lower'], df['BB_Middle'] = _calculate_bollinger_bands(df['Close'])
        df['ATR'] = _calculate_atr(df['High'], df['Low'], df['Close'])
        df['Volatility'] = _calculate_volatility(df['Close'])
        df['LogReturn'] = np.log(df['Close'] / df['Close'].shift(1))
        df['SMA_20'] = df['Close'].rolling(window = 20).mean()
        df['SMA_50'] = df['Close'].rolling(window = 50).mean()

        if 'Volume' in df.columns:
            df['Volume_SMA_20'] = df['Volume'].rolling(window = 20).mean()
            df['Volume_Ratio'] = df['Volume'] / df['Volume'].rolling(window = 20).mean()

        df.fillna(0, inplace = True)
        
        return df

    def reset(self, seed=None, options=None):
        super().reset(seed=seed, options=options)
        self.action_space.seed(int((self.np_random.uniform(0, seed if seed is not None else 1))))
        
        # Reset any internal flags or counters
        self._truncated = False
        self._current_tick = self._start_tick
        self._last_trade_tick = self._current_tick - 1
        self._position = Positions.Short
        self._position_history = (self.window_size * [None]) + [self._position]
        self._total_reward = 0.0
        self._total_profit = 1.0
        self._first_rendering = True
        self.history = {}
        
        # Important: Set these BEFORE calling _get_info()!
        self._balance = self.initial_balance
        self._shares_held = 0
        self._cost_basis = 0.0
        self._last_trade_tick = 0
        self._last_action = Actions.Hold.value
        self._position_size = 0
        self._total_profit = 1.0
        
        # Update portfolio value
        current_price = self.prices[self._current_tick]
        self._portfolio_value = self._balance + (self._shares_held * current_price)
        self._prev_portfolio_value = self._portfolio_value
        self._peak_portfolio_value = self._portfolio_value
        
        # Now safely get observation & info
        observation = self._get_observation()
        info = self._get_info()
        
        if self.render_mode == 'human':
            self._render_frame()
        
        return observation, info
    
    def step(self, action):
        self._truncated = False
        self._current_tick += 1
        self._last_action = action

        if self._current_tick == self._end_tick:
            self._truncated = True

        step_reward = self._calculate_reward(action)
        self._total_reward += step_reward

        self._update_profit(action)

        trade = False
        if (
            (action == Actions.Buy.value and self._position == Positions.Short) or
            (action == Actions.Sell.value and self._position == Positions.Long)
        ):
            trade = True

        if trade:
            self._position = self._position.opposite()
            self._last_trade_tick = self._current_tick

        self._position_history.append(self._position)
        observation = self._get_observation()
        info = self._get_info()
        self._update_history(info)

        if self.render_mode == 'human':
            self._render_frame()
            
        self._check_position_timeout()

        return observation, step_reward, False, self._truncated, info
    
    def _get_info(self):
        # Tính portofolio value
        current_price = self.prices[self._current_tick]
        portfolio_value = self._balance + (self._shares_held * current_price)


        # Chuyển vị thế sang chuỗi
        if self._position == Positions.Long:
            pos_str = 'Long'
        elif self._position == Positions.Short:
            pos_str = 'Short'
        else:
            pos_str = 'Flat'

        # Thêm các chỉ số kỹ thuật vào log
        detailed_info = {
            'balance': self._balance,
            'shares_held': self._shares_held,
            'last_action': self._last_action,
            'position': pos_str,
            'cost_basis': self._cost_basis,
            'portfolio_value': portfolio_value,
            'total_reward': self._total_reward,
            'total_profit': self._total_profit,
        }

        if self._current_tick < len(self.signal_features):
            current_tick_data = self.signal_features[self._current_tick]
            indicator_names = [
                'Close', 'RSI', 'MACD', 'MACD_Signal', 'MACD_Hist',
                'BB_Upper', 'BB_Middle', 'BB_Lower', 'ATR', 'Volatility',
                'LogReturn', 'SMA_20', 'SMA_50'
            ]
            if 'Volume' in self.df.columns:
                indicator_names += ['Volume', 'Volume_SMA_20', 'Volume_Ratio']

            indicators = {}
            for i, name in enumerate(indicator_names):
                if i < len(current_tick_data):
                    indicators[name] = current_tick_data[i]

            detailed_info.update(indicators)
        # print(detailed_info['balance'], detailed_info['shares_held'], detailed_info['last_action'], detailed_info['position'], detailed_info['total_reward'], detailed_info['total_profit'])
        return detailed_info
    
    # Copy từ gym_anytrading
    def _get_observation(self):
        return self.signal_features[(self._current_tick-self.window_size+1):self._current_tick+1]
    
    def _update_history(self, info):
        if not self.history:
            self.history = {key: [] for key in info.keys()}

        for key, value in info.items():
            self.history[key].append(value)
            
    def _render_frame(self):
        self.render()

    def render(self, mode='human'):
        def _plot_position(position, tick):
            color = None
            if position == Positions.Short:
                color = 'red'
            elif position == Positions.Long:
                color = 'green'
            if color:
                plt.scatter(tick, self.prices[tick], color=color, zorder=3)
    
        start_time = time()
    
        plt.cla()
    
        plt.plot(self.prices, label="Prices", zorder=1)
    
        for i in range(len(self._position_history)):
            position = self._position_history[i]
            # Only plot if not None
            if position is not None:
                _plot_position(position, i)

        plt.suptitle(
            f"Total Reward: {self._total_reward:.6f} ~ "
            f"Total Profit: {self._total_profit:.6f}"
        )
        plt.legend()
    
        end_time = time()
        process_time = end_time - start_time
        pause_time = (1 / self.metadata['render_fps']) - process_time
    
        pause_time = max(0, pause_time)
        plt.pause(pause_time)

    def render_all(self, title=None):
        window_ticks = np.arange(len(self._position_history))
        plt.plot(self.prices)

        short_ticks = []
        long_ticks = []
        for i, tick in enumerate(window_ticks):
            if self._position_history[i] == Positions.Short:
                short_ticks.append(tick)
            elif self._position_history[i] == Positions.Long:
                long_ticks.append(tick)

        plt.plot(short_ticks, self.prices[short_ticks], 'ro')
        plt.plot(long_ticks, self.prices[long_ticks], 'go')

        if title:
            plt.title(title)

        plt.suptitle(
            "Total Reward: %.6f" % self._total_reward + ' ~ ' +
            "Total Profit: %.6f" % self._total_profit
        )

    def close(self):
        plt.close()

    def save_rendering(self, filepath):
        plt.savefig(filepath)

    def pause_rendering(self):
        plt.show()
    
    def _process_data(self):
        raise NotImplementedError

    def _calculate_reward(self, action):
        raise NotImplementedError

    def _update_profit(self, action):
        raise NotImplementedError

    def max_possible_profit(self):
        raise NotImplementedError
    
    def _check_position_timeout(self):
        raise NotImplementedError

# %%
class VnStockEnv(TradingEnv):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self._short_obligations = 0

    def _process_data(self):
        """
        Improved data processing with better normalization techniques
        """
        prices = self.df.loc[:, 'Close'].to_numpy()
        prices = prices[self.frame_bound[0] - self.window_size : self.frame_bound[1]]

        # Prioritize medium and long-term indicators
        feature_columns = [
            'Close', 'RSI', 'MACD', 'MACD_Signal', 'MACD_Hist',
            'BB_Upper', 'BB_Lower', 'BB_Middle', 'ATR', 'Volatility',
            'LogReturn', 'SMA_20', 'SMA_50' 
        ]
        if 'Volume' in self.df.columns:
            feature_columns += ['Volume_SMA_20', 'Volume_Ratio']

        # Extract features
        features = self.df[feature_columns].to_numpy()
        features = features[self.frame_bound[0] - self.window_size : self.frame_bound[1]]

        # Setup normalized features array
        normalized_features = np.zeros_like(features)

        # Use a longer lookback period for more stable normalization
        lookback = min(100, self.window_size * 2)  # More stable lookback period

        for i in range(features.shape[0]):
            for j in range(features.shape[1]):
                feature_name = feature_columns[j]
                value = features[i, j]

                # Improved normalization based on feature type
                if feature_name == 'RSI':
                    # RSI is already normalized between 0-100, so just rescale to -1 to 1
                    normalized_features[i, j] = (value - 50) / 50
                elif 'Ratio' in feature_name:
                    # Log-transform ratios for better distribution
                    normalized_features[i, j] = np.log1p(value) if value > 0 else 0
                elif 'Return' in feature_name:
                    # Clip returns to reasonable range and normalize
                    normalized_features[i, j] = np.clip(value, -0.1, 0.1) / 0.1
                else:
                    # Calculate rolling mean and std using only past data
                    start_idx = max(0, i - lookback)
                    historical_data = features[start_idx:i+1, j]

                    if len(historical_data) > 10:  # Ensure enough data for stable statistics
                        # Use robust statistics - median and quantiles instead of mean/std
                        median = np.median(historical_data)
                        q75, q25 = np.percentile(historical_data, [75, 25])
                        iqr = max(q75 - q25, 1e-5)  # Avoid division by zero
                        normalized_features[i, j] = (value - median) / (iqr * 1.5)
                        # Clip extreme values
                        normalized_features[i, j] = np.clip(normalized_features[i, j], -3, 3)
                    else:
                        normalized_features[i, j] = 0

        return prices.astype(np.float32), normalized_features.astype(np.float32)

    def _calculate_reward(self, action: int) -> float:
        """
        Improved reward function that heavily discourages shorting in bullish trends
        """
        step_reward = 0
        trade = False
        current_price = self.prices[self._current_tick]
    
        # Calculate current portfolio value (accounting for short obligations)
        short_obligation_value = self._position_size * current_price if self._position == Positions.Short else 0
        current_portfolio_value = self._balance - short_obligation_value
        
        # Get the overall market trend
        long_term_trend = 0
        if self._current_tick >= 50:
            long_term_trend = (current_price - self.prices[self._current_tick - 50]) / self.prices[self._current_tick - 50]
    
        # Check if a trade occurs
        if (
            (action == Actions.Buy.value and self._position == Positions.Short) or
            (action == Actions.Sell.value and self._position == Positions.Long)
        ):
            trade = True
    
        # Major penalty for overtrading
        if trade:
            holding_period = self._current_tick - self._last_trade_tick
    
            # Strongly discourage frequent trading
            if holding_period < 30:  # Require minimum 10 periods between trades
                step_reward -= 1.0  # Substantial penalty
            else:
                # Still penalize trading but less severely
                step_reward -= 0.1
    
            # Strongly penalize shorting in bullish trends
            if action == Actions.Sell.value and long_term_trend > 0.02:  # Uptrend
                step_reward -= 1.0  # Increased penalty
    
            # Penalize buying in bearish trends
            if action == Actions.Buy.value and long_term_trend < -0.02:  # Downtrend
                step_reward -= 0.5
                
            # Penalize if _position_size (short) is too high
            if self._position_size > 0.8 * self.max_shares and self._position == Positions.Short and long_term_trend > 0.02:
                step_reward -= 2.0
    
        # STRONGER PENALTY FOR MAINTAINING SHORT POSITIONS IN BULLISH TREND
        if self._position == Positions.Short and long_term_trend > 0:
            # Exponential penalty for shorting in bullish trend
            days_in_position = self._current_tick - self._last_trade_tick
            step_reward -= 0.01 * days_in_position * abs(long_term_trend) * 50  # Grows over time
    
        # Calculate portfolio change - This is the main reward component
        pct_change = (current_portfolio_value - self._prev_portfolio_value) / max(self._prev_portfolio_value, 1.0)
    
        # Scale portfolio rewards based on holding period to reward longer-term holds
        holding_period = self._current_tick - self._last_trade_tick
        holding_multiplier = min(1.0 + (holding_period / 100), 3.0)
    
        step_reward += pct_change * 3.0 * holding_multiplier
    
        if self._position == Positions.Long and long_term_trend > 0:
            step_reward += 0.02  # Increased bonus for correctly riding uptrend
        elif self._position == Positions.Short and long_term_trend < -0.02:
            step_reward += 0.02  # Bonus only for correctly riding strong downtrend
    
        if current_portfolio_value > self._peak_portfolio_value:
            self._peak_portfolio_value = current_portfolio_value
    
        self._total_profit = current_portfolio_value / self.initial_balance
        self._prev_portfolio_value = current_portfolio_value
    
        return max(min(step_reward, 2.0), -2.0)

    def _update_profit(self, action):
        """
        Improved trading logic with more selective shorting and better position sizing
        """
        def _calculate_volatility():
            volatility = 0.02  # Default value
            if self._current_tick > 20:
                returns = np.diff(self.prices[self._current_tick-20:self._current_tick]) / self.prices[self._current_tick-20:self._current_tick-1]
                volatility = max(0.01, min(0.05, np.std(returns) * 5))
            return volatility

        def _calculate_position_size(volatility, is_short=False):
            if is_short:
                position_pct = 0.2 / volatility
                return min(0.3, max(0.05, position_pct))
            else:
                position_pct = 0.3 / volatility
                return min(0.5, max(0.1, position_pct))
            
        current_price = self.prices[self._current_tick]

        # ----- BUY ACTION -----
        if action == Actions.Buy.value:
            if self._position == Positions.Short:
                # CLEAR: BUY SHORT - Close short position
                self._last_trade_tick = self._current_tick  # Track when we traded
                cost_to_buy = self._position_size * current_price * (1 + self.trade_fee_bid_percent)
                self._balance -= cost_to_buy
                self._position_size = 0
                self._position = Positions.Flat
                self._total_profit = self._balance / self.initial_balance
                
            else:
                # CLEAR: BUY LONG - Open long position
                volatility = _calculate_volatility()
                position_pct = _calculate_position_size(volatility, is_short=False)

                shares_to_buy = min(
                    self.max_shares - self._shares_held,
                    int(self._balance * position_pct / (current_price * (1 + self.trade_fee_bid_percent)))
                )

                if shares_to_buy > 0:
                    self._last_trade_tick = self._current_tick  # Track when we traded
                    cost = shares_to_buy * current_price * (1 + self.trade_fee_bid_percent)
                    self._balance -= cost
                    if self._shares_held == 0:
                        self._cost_basis = current_price
                    else:
                        self._cost_basis = (
                            (self._shares_held * self._cost_basis)
                            + (shares_to_buy * current_price)
                        ) / (self._shares_held + shares_to_buy)

                    self._shares_held += shares_to_buy
                    self._position = Positions.Long
                    
        # ----- SELL ACTION -----
        elif action == Actions.Sell.value:
            if self._position == Positions.Long:
                # CLEAR: SELL LONG - Close long position
                if self._shares_held > 0:
                    self._last_trade_tick = self._current_tick
                    sale_proceeds = self._shares_held * current_price * (1 - self.trade_fee_ask_percent)
                    self._balance += sale_proceeds
                    self._total_profit = self._balance / self.initial_balance
                    self._shares_held = 0
                    self._cost_basis = 0
                    self._position = Positions.Flat

            elif self._position == Positions.Flat:
                # SELL SHORT - Open short position
                # Consider removing this constraint or making it configurable
                if True:  # removed trend constraint for consistency
                    volatility = _calculate_volatility()
                    position_pct = _calculate_position_size(volatility, is_short=True)

                    shares_to_short = min(
                        self.max_shares - self._position_size,
                        int(self._balance * position_pct / (current_price * (1 - self.trade_fee_bid_percent)))
                    )

                    if shares_to_short > 0:
                        self._last_trade_tick = self._current_tick
                        proceeds = shares_to_short * current_price * (1 - self.trade_fee_ask_percent)
                        self._balance += proceeds
                        self._position_size = shares_to_short
                        self._short_entry_price = current_price
                        self._position = Positions.Short
        
        # ----- HOLD ACTION -----
        elif action == Actions.Hold.value:
            pass
        
        # Cập nhật giá trị danh mục (portfolio)
        self._portfolio_value = self._balance + (self._shares_held * current_price)
        
        # Thanh lý vị thế khi kết thúc giao dịch (nếu có)
        if self._truncated:
            if self._shares_held > 0:
                sale_proceeds = self._shares_held * current_price * (1 - self.trade_fee_ask_percent)
                self._balance += sale_proceeds
                self._shares_held = 0
            elif self._position == Positions.Short:
                cost_to_buy = self._position_size * current_price * (1 + self.trade_fee_bid_percent)
                self._balance -= cost_to_buy
                self._position_size = 0
            
            self._total_profit = self._balance / self.initial_balance

    def max_possible_profit(self):
        """
        Tính lợi nhuận tối đa có thể đạt được nếu biết trước giá trị của mỗi tick
        """
        current_tick = self._start_tick
        last_trade_tick = current_tick - 1
        profit = 1.0
        position = Positions.Flat

        while current_tick <= self._end_tick:
            if position == Positions.Flat:
                if current_tick < self._end_tick - 1:
                    if self.prices[current_tick + 1] > self.prices[current_tick]:
                        position = Positions.Long
                        last_trade_tick = current_tick
                    elif self.prices[current_tick + 1] < self.prices[current_tick]:
                        position = Positions.Short
                        last_trade_tick = current_tick

            elif position == Positions.Long:
                if self.prices[current_tick] < self.prices[current_tick - 1]:
                    current_price = self.prices[current_tick]
                    last_price = self.prices[last_trade_tick]
                    shares = profit / last_price
                    profit = shares * current_price * (1 - self.trade_fee_ask_percent)
                    position = Positions.Flat

            elif position == Positions.Short:
                if self.prices[current_tick] > self.prices[current_tick - 1]:
                    current_price = self.prices[current_tick]
                    last_price = self.prices[last_trade_tick]
                    profit = profit * (2 - current_price / last_price) * (1 - self.trade_fee_bid_percent)
                    position = Positions.Flat

            current_tick += 1

        if position == Positions.Long:
            current_price = self.prices[self._end_tick]
            last_price = self.prices[last_trade_tick]
            shares = profit / last_price
            profit = shares * current_price * (1 - self.trade_fee_ask_percent)
        elif position == Positions.Short:
            current_price = self.prices[self._end_tick]
            last_price = self.prices[last_trade_tick]
            profit = profit * (2 - current_price / last_price) * (1 - self.trade_fee_bid_percent)

        return profit
    
    def _check_position_timeout(self):
        """Force close long-held positions, especially shorts in bullish trends"""
        if self._position == Positions.Flat:
            return
            
        holding_period = self._current_tick - self._last_trade_tick
        current_price = self.prices[self._current_tick]
        long_term_trend = 0
        
        if self._current_tick >= 50:
            long_term_trend = (current_price - self.prices[self._current_tick - 50]) / self.prices[self._current_tick - 50]
        
        # Force close shorts in bullish trends after a shorter period
        if self._position == Positions.Short and long_term_trend > 0.02 and holding_period > 15:
            # Close short position
            cost_to_buy = self._position_size * current_price * (1 + self.trade_fee_bid_percent)
            self._balance -= cost_to_buy
            self._position_size = 0
            self._position = Positions.Flat
            
        # Force close any position after very long hold
        elif holding_period > 50:
            if self._position == Positions.Long:
                # Close long position
                sale_proceeds = self._shares_held * current_price * (1 - self.trade_fee_ask_percent)
                self._balance += sale_proceeds
                self._shares_held = 0
                self._position = Positions.Flat
                
            elif self._position == Positions.Short:
                # Close short position
                cost_to_buy = self._position_size * current_price * (1 + self.trade_fee_bid_percent)
                self._balance -= cost_to_buy
                self._position_size = 0
                self._position = Positions.Flat

# %% [markdown]
# # PPO

# %%
log_dir = "logs/"
os.makedirs(log_dir, exist_ok=True)

env = VnStockEnv(
    df=df,
    window_size=25,
    frame_bound=(25, len(df)),
    initial_balance=2000,
    max_shares=100,
    render_mode=None
)

check_env(env, warn=True)

env = Monitor(env, log_dir)
env = DummyVecEnv([lambda: env])

model = PPO(
    "MlpPolicy", 
    env, 
    learning_rate=5e-5,  
    gamma=0.95,  
    gae_lambda=0.95,
    clip_range=0.2,
    n_epochs=25,
    n_steps=2048,
    ent_coef=0.2, 
    vf_coef=0.5,
    max_grad_norm=0.5,
    verbose=1
)
model.learn(1000000)


model.save("ppo_trading_env")


mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward}, Std: {std_reward}")
# Out:
# Using cuda device
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.72e+03 |
# |    ep_rew_mean     | -538     |
# | time/              |          |
# |    fps             | 253      |
# |    iterations      | 1        |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -515        |
# | time/                   |             |
# |    fps                  | 181         |
# |    iterations           | 2           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010383496 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0152     |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.57        |
# |    n_updates            | 25          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 3.11        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -516        |
# | time/                   |             |
# |    fps                  | 165         |
# |    iterations           | 3           |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009808933 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.499       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0248     |
# |    value_loss           | 1.69        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -511        |
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 4           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009884313 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.56        |
# |    n_updates            | 75          |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 1.55        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -500        |
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 5           |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010006404 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.105       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 1.28        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -482        |
# | time/                   |             |
# |    fps                  | 153         |
# |    iterations           | 6           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.006000847 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.504       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.315       |
# |    n_updates            | 125         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 1.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -473        |
# | time/                   |             |
# |    fps                  | 152         |
# |    iterations           | 7           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007234632 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.987      |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.383       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 1.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -464        |
# | time/                   |             |
# |    fps                  | 151         |
# |    iterations           | 8           |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010006367 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.957      |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.155       |
# |    n_updates            | 175         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 1.06        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -457        |
# | time/                   |             |
# |    fps                  | 150         |
# |    iterations           | 9           |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.008131137 |
# |    clip_fraction        | 0.058       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.947      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0244      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 0.863       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -453        |
# | time/                   |             |
# |    fps                  | 149         |
# |    iterations           | 10          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006831071 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.114       |
# |    n_updates            | 225         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 0.824       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -447         |
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 11           |
# |    time_elapsed         | 150          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0063603795 |
# |    clip_fraction        | 0.0395       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.935       |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.122        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0178      |
# |    value_loss           | 0.808        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -443         |
# | time/                   |              |
# |    fps                  | 149          |
# |    iterations           | 12           |
# |    time_elapsed         | 164          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0068248594 |
# |    clip_fraction        | 0.0477       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.933       |
# |    explained_variance   | 0.777        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0772       |
# |    n_updates            | 275          |
# |    policy_gradient_loss | -0.0222      |
# |    value_loss           | 0.99         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -440        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 13          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007902192 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.92       |
# |    explained_variance   | 0.825       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.000202   |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 0.717       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -437         |
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 14           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0073750503 |
# |    clip_fraction        | 0.0626       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.924       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.279        |
# |    n_updates            | 325          |
# |    policy_gradient_loss | -0.0206      |
# |    value_loss           | 0.817        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -434        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 15          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008494014 |
# |    clip_fraction        | 0.0653      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00226     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.766       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -427        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 16          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006730965 |
# |    clip_fraction        | 0.0509      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0447     |
# |    n_updates            | 375         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 0.665       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -423        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 17          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.005753408 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.157       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0183     |
# |    value_loss           | 0.682       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+03   |
# |    ep_rew_mean          | -421       |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 18         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.00686065 |
# |    clip_fraction        | 0.0511     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.915     |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.00328   |
# |    n_updates            | 425        |
# |    policy_gradient_loss | -0.0203    |
# |    value_loss           | 0.691      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -416        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 19          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007261303 |
# |    clip_fraction        | 0.0654      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0487     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.024      |
# |    value_loss           | 0.604       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -415        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 20          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008153891 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0298     |
# |    n_updates            | 475         |
# |    policy_gradient_loss | -0.017      |
# |    value_loss           | 0.714       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -413        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 21          |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.007122332 |
# |    clip_fraction        | 0.0607      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0827      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 0.754       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -409        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 22          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007656942 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0514      |
# |    n_updates            | 525         |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 0.613       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -408        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 23          |
# |    time_elapsed         | 319         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008335497 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0335     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 0.775       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+03   |
# |    ep_rew_mean          | -406       |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 24         |
# |    time_elapsed         | 332        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00751317 |
# |    clip_fraction        | 0.048      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.913     |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.0594     |
# |    n_updates            | 575        |
# |    policy_gradient_loss | -0.0209    |
# |    value_loss           | 0.686      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -406        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 25          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008139709 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0572     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0236     |
# |    value_loss           | 0.649       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -404         |
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 26           |
# |    time_elapsed         | 361          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0054239677 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.941       |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0885       |
# |    n_updates            | 625          |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 1.06         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -401         |
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 27           |
# |    time_elapsed         | 375          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0070831273 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.91        |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0955       |
# |    n_updates            | 650          |
# |    policy_gradient_loss | -0.0231      |
# |    value_loss           | 0.792        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -400        |
# | time/                   |             |
# |    fps                  | 146         |
# |    iterations           | 28          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008103985 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.918      |
# |    explained_variance   | 0.816       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0199      |
# |    n_updates            | 675         |
# |    policy_gradient_loss | -0.0262     |
# |    value_loss           | 0.597       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+03   |
# |    ep_rew_mean          | -399       |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 29         |
# |    time_elapsed         | 403        |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00605324 |
# |    clip_fraction        | 0.0526     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.903     |
# |    explained_variance   | 0.805      |
# |    learning_rate        | 5e-05      |
# |    loss                 | 0.2        |
# |    n_updates            | 700        |
# |    policy_gradient_loss | -0.0247    |
# |    value_loss           | 0.735      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.72e+03   |
# |    ep_rew_mean          | -398       |
# | time/                   |            |
# |    fps                  | 147        |
# |    iterations           | 30         |
# |    time_elapsed         | 417        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00910257 |
# |    clip_fraction        | 0.0698     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.904     |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 5e-05      |
# |    loss                 | -0.0775    |
# |    n_updates            | 725        |
# |    policy_gradient_loss | -0.0242    |
# |    value_loss           | 0.541      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -398        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 31          |
# |    time_elapsed         | 431         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010777139 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.923      |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.359       |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -396        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 32          |
# |    time_elapsed         | 445         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006935502 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.781       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0301     |
# |    n_updates            | 775         |
# |    policy_gradient_loss | -0.023      |
# |    value_loss           | 0.635       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -396        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 33          |
# |    time_elapsed         | 458         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008363574 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.105       |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 0.607       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -395        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 34          |
# |    time_elapsed         | 472         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007400722 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.91       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00576     |
# |    n_updates            | 825         |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 0.72        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -394        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 35          |
# |    time_elapsed         | 486         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008026326 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.855       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0061      |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0242     |
# |    value_loss           | 0.558       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -393        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 36          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.007423018 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0248      |
# |    n_updates            | 875         |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 0.486       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -393         |
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 37           |
# |    time_elapsed         | 514          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0069196573 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.823        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0196       |
# |    n_updates            | 900          |
# |    policy_gradient_loss | -0.0239      |
# |    value_loss           | 0.694        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -391        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 38          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.008996009 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.888      |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.1        |
# |    n_updates            | 925         |
# |    policy_gradient_loss | -0.0235     |
# |    value_loss           | 0.476       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -391         |
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 39           |
# |    time_elapsed         | 541          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0062761744 |
# |    clip_fraction        | 0.04         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.904       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.102        |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0211      |
# |    value_loss           | 0.772        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -391        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 40          |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.006156831 |
# |    clip_fraction        | 0.0462      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0861      |
# |    n_updates            | 975         |
# |    policy_gradient_loss | -0.0258     |
# |    value_loss           | 0.654       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -390         |
# | time/                   |              |
# |    fps                  | 147          |
# |    iterations           | 41           |
# |    time_elapsed         | 569          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0072603244 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.887       |
# |    explained_variance   | 0.826        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0458       |
# |    n_updates            | 1000         |
# |    policy_gradient_loss | -0.0255      |
# |    value_loss           | 0.637        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -390        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 42          |
# |    time_elapsed         | 582         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009030795 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.917      |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.089       |
# |    n_updates            | 1025        |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.938       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -389        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 43          |
# |    time_elapsed         | 596         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008578696 |
# |    clip_fraction        | 0.0733      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.895      |
# |    explained_variance   | 0.83        |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00771     |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 0.674       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -388        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 44          |
# |    time_elapsed         | 610         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009516561 |
# |    clip_fraction        | 0.0853      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0732     |
# |    n_updates            | 1075        |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 0.526       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -388        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 45          |
# |    time_elapsed         | 624         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.009122858 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.902      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.024       |
# |    n_updates            | 1100        |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 0.585       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -388        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 46          |
# |    time_elapsed         | 638         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.008434834 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.916      |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0242      |
# |    n_updates            | 1125        |
# |    policy_gradient_loss | -0.0277     |
# |    value_loss           | 0.679       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -387        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 47          |
# |    time_elapsed         | 651         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.009007189 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.801       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.00985     |
# |    n_updates            | 1150        |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 0.739       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -387        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 48          |
# |    time_elapsed         | 664         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009243138 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.901      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.155      |
# |    n_updates            | 1175        |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 0.679       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -386        |
# | time/                   |             |
# |    fps                  | 147         |
# |    iterations           | 49          |
# |    time_elapsed         | 678         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008030199 |
# |    clip_fraction        | 0.0711      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0798     |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.0303     |
# |    value_loss           | 0.593       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -386        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 50          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008830485 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0491     |
# |    n_updates            | 1225        |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 0.583       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.72e+03     |
# |    ep_rew_mean          | -386         |
# | time/                   |              |
# |    fps                  | 148          |
# |    iterations           | 51           |
# |    time_elapsed         | 704          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0073752953 |
# |    clip_fraction        | 0.0512       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.919       |
# |    explained_variance   | 0.753        |
# |    learning_rate        | 5e-05        |
# |    loss                 | 0.0511       |
# |    n_updates            | 1250         |
# |    policy_gradient_loss | -0.0244      |
# |    value_loss           | 0.849        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -386        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 52          |
# |    time_elapsed         | 718         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008448528 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0547     |
# |    n_updates            | 1275        |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 0.71        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -385        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 53          |
# |    time_elapsed         | 731         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008487718 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0363      |
# |    n_updates            | 1300        |
# |    policy_gradient_loss | -0.0282     |
# |    value_loss           | 0.761       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -384        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 54          |
# |    time_elapsed         | 745         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.007866101 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.899      |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.0465      |
# |    n_updates            | 1325        |
# |    policy_gradient_loss | -0.0316     |
# |    value_loss           | 0.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -384        |
# | time/                   |             |
# |    fps                  | 148         |
# |    iterations           | 55          |
# |    time_elapsed         | 758         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.007603996 |
# |    clip_fraction        | 0.063       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.906      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0638     |
# |    n_updates            | 1350        |
# ...
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 450         |
# |    time_elapsed         | 4934        |
# |    total_timesteps      | 921600      |
# | train/                  |             |
# |    approx_kl            | 0.010952951 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0758     |
# |    n_updates            | 11225       |
# |    policy_gradient_loss | -0.0382     |
# |    value_loss           | 0.528       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 451         |
# |    time_elapsed         | 4944        |
# |    total_timesteps      | 923648      |
# | train/                  |             |
# |    approx_kl            | 0.010830402 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.84       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.059      |
# |    n_updates            | 11250       |
# |    policy_gradient_loss | -0.0384     |
# |    value_loss           | 0.44        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 452         |
# |    time_elapsed         | 4954        |
# |    total_timesteps      | 925696      |
# | train/                  |             |
# |    approx_kl            | 0.008948562 |
# |    clip_fraction        | 0.0685      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 5e-05       |
# |    loss                 | 0.111       |
# |    n_updates            | 11275       |
# |    policy_gradient_loss | -0.0279     |
# |    value_loss           | 1.05        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 453         |
# |    time_elapsed         | 4965        |
# |    total_timesteps      | 927744      |
# | train/                  |             |
# |    approx_kl            | 0.010500752 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.84        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0424     |
# |    n_updates            | 11300       |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 0.426       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 454         |
# |    time_elapsed         | 4975        |
# |    total_timesteps      | 929792      |
# | train/                  |             |
# |    approx_kl            | 0.010810141 |
# |    clip_fraction        | 0.0982      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.847      |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0519     |
# |    n_updates            | 11325       |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 0.527       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 455         |
# |    time_elapsed         | 4985        |
# |    total_timesteps      | 931840      |
# | train/                  |             |
# |    approx_kl            | 0.011149714 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.122      |
# |    n_updates            | 11350       |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 0.43        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 456         |
# |    time_elapsed         | 4995        |
# |    total_timesteps      | 933888      |
# | train/                  |             |
# |    approx_kl            | 0.012666203 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.1        |
# |    n_updates            | 11375       |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 0.481       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 186         |
# |    iterations           | 457         |
# |    time_elapsed         | 5005        |
# |    total_timesteps      | 935936      |
# | train/                  |             |
# |    approx_kl            | 0.011306336 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.866      |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0278     |
# |    n_updates            | 11400       |
# |    policy_gradient_loss | -0.0336     |
# |    value_loss           | 0.786       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 458         |
# |    time_elapsed         | 5015        |
# |    total_timesteps      | 937984      |
# | train/                  |             |
# |    approx_kl            | 0.010801912 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0741     |
# |    n_updates            | 11425       |
# |    policy_gradient_loss | -0.0391     |
# |    value_loss           | 0.451       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 459         |
# |    time_elapsed         | 5025        |
# |    total_timesteps      | 940032      |
# | train/                  |             |
# |    approx_kl            | 0.012123506 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0377     |
# |    n_updates            | 11450       |
# |    policy_gradient_loss | -0.0388     |
# |    value_loss           | 0.577       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -354        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 460         |
# |    time_elapsed         | 5036        |
# |    total_timesteps      | 942080      |
# | train/                  |             |
# |    approx_kl            | 0.011598922 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.859      |
# |    explained_variance   | 0.799       |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0796     |
# |    n_updates            | 11475       |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 0.582       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.72e+03    |
# |    ep_rew_mean          | -353        |
# | time/                   |             |
# |    fps                  | 187         |
# |    iterations           | 461         |
# |    time_elapsed         | 5046        |
# |    total_timesteps      | 944128      |
# | train/                  |             |
# |    approx_kl            | 0.010784315 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 5e-05       |
# |    loss                 | -0.0387     |
# |    n_updates            | 11500       |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 0.533       |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 32
#      16 env = DummyVecEnv([lambda: env])
#      18 model = PPO(
#      19     "MlpPolicy",
#      20     env,
#    (...)
#      30     verbose=1
#      31 )
# ---> 32 model.learn(1000000)
#      35 model.save("ppo_trading_env")
#      38 mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\stable_baselines3\ppo\ppo.py:311, in PPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     302 def learn(
#     303     self: SelfPPO,
#     304     total_timesteps: int,
#    (...)
#     309     progress_bar: bool = False,
#     310 ) -> SelfPPO:
# --> 311     return super().learn(
#     312         total_timesteps=total_timesteps,
#     313         callback=callback,
#     314         log_interval=log_interval,
#     315         tb_log_name=tb_log_name,
#     316         reset_num_timesteps=reset_num_timesteps,
#     317         progress_bar=progress_bar,
#     318     )
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:323, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     320 assert self.env is not None
#     322 while self.num_timesteps < total_timesteps:
# --> 323     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325     if not continue_training:
#     326         break
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:202, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     199 with th.no_grad():
#     200     # Convert to pytorch tensor or to TensorDict
#     201     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 202     actions, values, log_probs = self.policy(obs_tensor)
#     203 actions = actions.cpu().numpy()
#     205 # Rescale and perform action
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\torch\nn\modules\module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\torch\nn\modules\module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\stable_baselines3\common\policies.py:654, in ActorCriticPolicy.forward(self, obs, deterministic)
#     652 # Evaluate the values for the given observations
#     653 values = self.value_net(latent_vf)
# --> 654 distribution = self._get_action_dist_from_latent(latent_pi)
#     655 actions = distribution.get_actions(deterministic=deterministic)
#     656 log_prob = distribution.log_prob(actions)
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\stable_baselines3\common\policies.py:697, in ActorCriticPolicy._get_action_dist_from_latent(self, latent_pi)
#     694     return self.action_dist.proba_distribution(mean_actions, self.log_std)
#     695 elif isinstance(self.action_dist, CategoricalDistribution):
#     696     # Here mean_actions are the logits before the softmax
# --> 697     return self.action_dist.proba_distribution(action_logits=mean_actions)
#     698 elif isinstance(self.action_dist, MultiCategoricalDistribution):
#     699     # Here mean_actions are the flattened logits
#     700     return self.action_dist.proba_distribution(action_logits=mean_actions)
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\stable_baselines3\common\distributions.py:288, in CategoricalDistribution.proba_distribution(self, action_logits)
#     287 def proba_distribution(self: SelfCategoricalDistribution, action_logits: th.Tensor) -> SelfCategoricalDistribution:
# --> 288     self.distribution = Categorical(logits=action_logits)
#     289     return self
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\torch\distributions\categorical.py:70, in Categorical.__init__(self, probs, logits, validate_args)
#      66 self._num_events = self._param.size()[-1]
#      67 batch_shape = (
#      68     self._param.size()[:-1] if self._param.ndimension() > 1 else torch.Size()
#      69 )
# ---> 70 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\nguye\anaconda3\envs\ai\Lib\site-packages\torch\distributions\distribution.py:67, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      65         value = getattr(self, param)
#      66         valid = constraint.check(value)
# ---> 67         if not valid.all():
#      68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#    (...)
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# KeyboardInterrupt:

# %%
def plot_trading_strategy(env, model, df):
    """
    Enhanced plot of trading strategy showing long/short positions with comprehensive metrics.
    """
    # Reset the environment to get the initial state
    obs = env.reset()
    
    # Initialize lists for logging data
    prices = []
    portfolio_values = []
    actions = []
    positions = []  # Track the position state
    dates = []
    
    # For tracking performance metrics
    trades = []
    current_position = "flat"  # Start with flat position
    entry_price = 0
    entry_date = None
    entry_action = None

    done = False
    while not done:
        # Get action from model (deterministic for evaluation)
        action, _ = model.predict(obs, deterministic=True)
        
        # Step through the environment
        obs, reward, done, info = env.step(action)
        
        # Retrieve environment attributes
        current_tick = env.get_attr('_current_tick')[0]
        start_tick = env.get_attr('_start_tick')[0]
        window_size = env.get_attr('window_size')[0]
        
        date_index = current_tick - start_tick + window_size
        if date_index < len(df.index):
            current_date = df.index[date_index]
            dates.append(current_date)
        else:
            break
        
        # Log the price and portfolio value at the current tick
        current_price = env.get_attr('prices')[0][current_tick]
        current_portfolio_value = env.get_attr('_portfolio_value')[0]
        
        # Get the current position from the environment
        position_state = env.get_attr('_position')[0]
        
        prices.append(current_price)
        portfolio_values.append(current_portfolio_value)
        actions.append(action[0])
        positions.append(position_state)
        
        # Track trade information based on the action and position
        if action[0] == 0:  # Buy action
            if position_state == 1:  # Buy closing a short position
                if current_position == "short":
                    profit_pct = (entry_price - current_price) / entry_price * 100
                    trades.append({
                        'entry_date': entry_date,
                        'exit_date': current_date,
                        'entry_price': entry_price,
                        'exit_price': current_price,
                        'profit_pct': profit_pct,
                        'holding_days': (current_date - entry_date).days,
                        'type': 'short'
                    })
                current_position = "flat"
            elif position_state == 2:  # Buy opening a long position
                current_position = "long"
                entry_price = current_price
                entry_date = current_date
                entry_action = "buy_long"
                
        elif action[0] == 1:  # Sell action
            if position_state == 1:  # Sell closing a long position
                if current_position == "long":
                    profit_pct = (current_price - entry_price) / entry_price * 100
                    trades.append({
                        'entry_date': entry_date,
                        'exit_date': current_date,
                        'entry_price': entry_price,
                        'exit_price': current_price,
                        'profit_pct': profit_pct,
                        'holding_days': (current_date - entry_date).days,
                        'type': 'long'
                    })
                current_position = "flat"
            elif position_state == 0:  # Sell opening a short position
                current_position = "short"
                entry_price = current_price
                entry_date = current_date
                entry_action = "sell_short"
    
    # Create figure with two subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10), gridspec_kw={'height_ratios': [3, 1]})
    
    # Plot price with buy/sell markers
    ax1.plot(dates, prices, label='Price', color='blue', linewidth=1.5)
    
    # Add a trendline
    z = np.polyfit(range(len(dates)), prices, 1)
    p = np.poly1d(z)
    ax1.plot(dates, p(range(len(dates))), "b--", linewidth=1, alpha=0.7, label='Trend')
    
    # Identify different action types
    buy_long_idx = []
    sell_long_idx = []
    buy_short_idx = []
    sell_short_idx = []
    
    for i in range(len(actions)):
        if i > 0:  # Skip first item to avoid index errors
            if actions[i] == 0:  # Buy action
                if positions[i-1] == 0:  # Previous position was Short
                    buy_short_idx.append(i)  # Closing a short position
                else:
                    buy_long_idx.append(i)   # Opening a long position
            elif actions[i] == 1:  # Sell action
                if positions[i-1] == 2:  # Previous position was Long
                    sell_long_idx.append(i)  # Closing a long position
                else:
                    sell_short_idx.append(i)  # Opening a short position
    
    # Plot the different action types with different markers
    buy_long_dates = [dates[i] for i in buy_long_idx]
    buy_long_prices = [prices[i] for i in buy_long_idx]
    ax1.scatter(buy_long_dates, buy_long_prices, color='green', label='Buy Long', marker='^', s=100)
    
    sell_long_dates = [dates[i] for i in sell_long_idx]
    sell_long_prices = [prices[i] for i in sell_long_idx]
    ax1.scatter(sell_long_dates, sell_long_prices, color='red', label='Sell Long', marker='v', s=100)
    
    sell_short_dates = [dates[i] for i in sell_short_idx]
    sell_short_prices = [prices[i] for i in sell_short_idx]
    ax1.scatter(sell_short_dates, sell_short_prices, color='purple', label='Sell Short', marker='d', s=100)
    
    buy_short_dates = [dates[i] for i in buy_short_idx]
    buy_short_prices = [prices[i] for i in buy_short_idx]
    ax1.scatter(buy_short_dates, buy_short_prices, color='orange', label='Buy Short', marker='s', s=100)
    
    # Identify and highlight long and short position periods
    long_periods = []
    short_periods = []
    
    current_long_start = None
    current_short_start = None
    
    for i in range(len(positions)):
        pos = positions[i]
        
        if pos == 2:  # Long position
            if current_long_start is None:
                current_long_start = i
            if current_short_start is not None:
                short_periods.append((current_short_start, i-1))
                current_short_start = None
        elif pos == 0:  # Short position
            if current_short_start is None:
                current_short_start = i
            if current_long_start is not None:
                long_periods.append((current_long_start, i-1))
                current_long_start = None
        elif pos == 1:  # Flat position
            if current_long_start is not None:
                long_periods.append((current_long_start, i-1))
                current_long_start = None
            if current_short_start is not None:
                short_periods.append((current_short_start, i-1))
                current_short_start = None
    
    # Close any open periods
    if current_long_start is not None:
        long_periods.append((current_long_start, len(positions)-1))
    if current_short_start is not None:
        short_periods.append((current_short_start, len(positions)-1))
    
    # Highlight long periods with light green background
    for start_idx, end_idx in long_periods:
        ax1.axvspan(dates[start_idx], dates[end_idx], color='green', alpha=0.1, label='_nolegend_')
    
    # Highlight short periods with light red background
    for start_idx, end_idx in short_periods:
        ax1.axvspan(dates[start_idx], dates[end_idx], color='red', alpha=0.1, label='_nolegend_')
    
    # Add position indicator at the bottom of the chart
    flat_color = 'gray'
    long_color = 'green'
    short_color = 'red'
    
    ax1.set_title('Trading Strategy Performance', fontsize=15)
    ax1.set_ylabel('Price', fontsize=12)
    ax1.grid(True, alpha=0.3)
    ax1.legend(loc='upper left')
    
    # Portfolio value subplot
    ax2.plot(dates, portfolio_values, label='Portfolio Value', color='purple', linewidth=1.5)
    
    # Add position indicator to portfolio chart
    position_colors = []
    for pos in positions:
        if pos == 1:  # Flat
            position_colors.append(flat_color)
        elif pos == 2:  # Long
            position_colors.append(long_color)
        elif pos == 0:  # Short
            position_colors.append(short_color)
    
    # Calculate drawdowns
    portfolio_array = np.array(portfolio_values)
    running_max = np.maximum.accumulate(portfolio_array)
    drawdowns = (portfolio_array - running_max) / running_max * 100
    
    # Highlight major drawdown periods
    drawdown_threshold = -5  # 5% drawdown threshold
    is_drawdown = drawdowns <= drawdown_threshold
    
    # Find drawdown periods
    drawdown_starts = []
    drawdown_ends = []
    in_drawdown = False
    
    for i, is_dd in enumerate(is_drawdown):
        if is_dd and not in_drawdown:
            drawdown_starts.append(i)
            in_drawdown = True
        elif not is_dd and in_drawdown:
            drawdown_ends.append(i)
            in_drawdown = False
    
    if in_drawdown:
        drawdown_ends.append(len(is_drawdown) - 1)
    
    # Highlight drawdown periods
    # for start, end in zip(drawdown_starts, drawdown_ends):
    #     ax2.axvspan(dates[start], dates[end], color='red', alpha=0.2, label='_nolegend_')
    
    # Add a trendline for portfolio value
    if len(portfolio_values) > 1:
        z = np.polyfit(range(len(dates)), portfolio_values, 1)
        p = np.poly1d(z)
        ax2.plot(dates, p(range(len(dates))), "purple", linestyle='--', 
                 linewidth=1, alpha=0.7, label='Portfolio Trend')
    
    ax2.set_xlabel('Date', fontsize=12)
    ax2.set_ylabel('Portfolio Value', fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.legend(loc='upper left')
    
    # Format date axes
    date_formatter = DateFormatter('%Y-%m-%d')
    ax1.xaxis.set_major_formatter(date_formatter)
    ax2.xaxis.set_major_formatter(date_formatter)
    plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45)
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45)
    
    plt.tight_layout()
    
    # Calculate and display performance metrics
    # Separate buy/sell counts for long and short
    buy_long_count = len(buy_long_idx)
    sell_long_count = len(sell_long_idx)
    buy_short_count = len(buy_short_idx)
    sell_short_count = len(sell_short_idx)
    
    # Count periods where position is flat
    flat_count = positions.count(1)
    
    # Calculate long and short trade statistics
    long_trades = [t for t in trades if t['type'] == 'long']
    short_trades = [t for t in trades if t['type'] == 'short']
    
    if portfolio_values:
        initial_portfolio = portfolio_values[0]
        final_portfolio = portfolio_values[-1]
        max_portfolio = max(portfolio_values)
        
        # Calculate annualized return
        days = (dates[-1] - dates[0]).days
        years = days / 365.0
        annualized_return = ((final_portfolio / initial_portfolio) ** (1/years) - 1) * 100 if years > 0 else 0
        
        # Calculate drawdown
        max_drawdown = min(drawdowns) if len(drawdowns) > 0 else 0
        
        # Calculate win rates
        long_win_rate = len([t for t in long_trades if t['profit_pct'] > 0]) / len(long_trades) if long_trades else 0
        short_win_rate = len([t for t in short_trades if t['profit_pct'] > 0]) / len(short_trades) if short_trades else 0
        overall_win_rate = len([t for t in trades if t['profit_pct'] > 0]) / len(trades) if trades else 0
        
        # Calculate average profit per trade
        long_avg_profit = sum(t['profit_pct'] for t in long_trades) / len(long_trades) if long_trades else 0
        short_avg_profit = sum(t['profit_pct'] for t in short_trades) / len(short_trades) if short_trades else 0
        overall_avg_profit = sum(t['profit_pct'] for t in trades) / len(trades) if trades else 0
        
        # Calculate Sharpe ratio (simplified)
        returns = []
        for i in range(1, len(portfolio_values)):
            daily_return = (portfolio_values[i] - portfolio_values[i-1]) / portfolio_values[i-1]
            returns.append(daily_return)
        
        avg_return = np.mean(returns) if returns else 0
        std_return = np.std(returns) if returns else 1
        sharpe = avg_return / std_return * np.sqrt(252) if std_return > 0 else 0
        
        # Print performance metrics
        print("\n===== TRADING PERFORMANCE SUMMARY =====")
        print(f"\n--- Position Summary ---")
        print(f"Long Positions: {len(long_periods)}")
        print(f"Short Positions: {len(short_periods)}")
        print(f"Flat Position Periods: {flat_count}")
        
        print(f"\n--- Action Summary ---")
        print(f"Buy Long Actions: {buy_long_count}")
        print(f"Sell Long Actions: {sell_long_count}")
        print(f"Sell Short Actions: {sell_short_count}")
        print(f"Buy Short Actions: {buy_short_count}")
        
        print(f"\n--- Trade Statistics ---")
        print(f"Total Trades: {len(trades)}")
        print(f"Long Trades: {len(long_trades)}")
        print(f"Short Trades: {len(short_trades)}")
        
        print(f"Overall Win Rate: {overall_win_rate:.2%}")
        print(f"Long Win Rate: {long_win_rate:.2%}")
        print(f"Short Win Rate: {short_win_rate:.2%}")
        
        print(f"Overall Avg Profit: {overall_avg_profit:.2f}%")
        print(f"Long Avg Profit: {long_avg_profit:.2f}%")
        print(f"Short Avg Profit: {short_avg_profit:.2f}%")
        
        print(f"\n--- Portfolio Performance ---")
        print(f"Initial Portfolio Value: {initial_portfolio:.2f}")
        print(f"Final Portfolio Value: {final_portfolio:.2f}")
        print(f"Maximum Portfolio Value: {max_portfolio:.2f}")
        print(f"Total Return: {(final_portfolio/initial_portfolio - 1) * 100:.2f}%")
        print(f"Annualized Return: {annualized_return:.2f}%")
        print(f"Maximum Drawdown: {max_drawdown:.2f}%")
        print(f"Sharpe Ratio: {sharpe:.2f}")
    else:
        print("No portfolio data available for performance calculation.")
        
    return fig

# %%
# Lấy dữ liệu chứng khoán FPT từ VCI năm 2024 - 2025
stock = Vnstock().stock(symbol='FPT', source='VCI')
df = stock.quote.history(start='2024-01-01', end='2025-03-17')

#Đổi tên cột thoả mãn với gym anytrading
df.rename(columns={
    'time': 'Date',
    'open': 'Open',
    'high': 'High',
    'low': 'Low',
    'close': 'Close',
    'volume': 'Volume'
}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])  # Chuyển đổi sang định dạng datetime
df.set_index('Date', inplace=True)  # Đặt cột Date làm index
df


eval_env = VnStockEnv(
    df=df,
    window_size=25,
    frame_bound=(25, len(df)),
    initial_balance=10000,
    max_shares=150,
    render_mode=None  # Disable real-time rendering during evaluation
)

eval_env = Monitor(eval_env)
eval_env = DummyVecEnv([lambda: eval_env])

# Plot the trading strategy
fig = plot_trading_strategy(eval_env, model, df)
# Out:
# 2025-03-19 10:54:02 - vnstock.common.data.data_explorer - WARNING - Thông tin niêm yết & giao dịch sẽ được truy xuất từ TCBS
# ===== TRADING PERFORMANCE SUMMARY =====
#
# --- Position Summary ---
# Long Positions: 13
# Short Positions: 18
# Flat Position Periods: 59
#
# --- Action Summary ---
# Buy Long Actions: 110
# Sell Long Actions: 6
# Sell Short Actions: 9
# Buy Short Actions: 12
#
# --- Trade Statistics ---
# Total Trades: 0
# Long Trades: 0
# Short Trades: 0
# Overall Win Rate: 0.00%
# Long Win Rate: 0.00%
# Short Win Rate: 0.00%
# Overall Avg Profit: 0.00%
# Long Avg Profit: 0.00%
# Short Avg Profit: 0.00%
#
# --- Portfolio Performance ---
# Initial Portfolio Value: 10000.00
# Final Portfolio Value: 10000.00
# Maximum Portfolio Value: 14142.06
# Total Return: 0.00%
# Annualized Return: 0.00%
# Maximum Drawdown: -33.93%
# Sharpe Ratio: 0.59
